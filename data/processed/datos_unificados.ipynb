# %%
#datasets en pandas de datos_universitarios_inegi_2015-2022.csv
ruta_archivo = "datos_unificados_2015_2020.csv"
import pandas as pd

df = pd.read_csv(ruta_archivo) 
df.head()
# Out:
#    id_estado           estado   año      gini  salario_mensual_promedio  \
# 0          1   Aguascalientes  2015       NaN               3441.567358
# 1          1   Aguascalientes  2016  0.409074               3549.550848
# 2          1   Aguascalientes  2017       NaN               3518.302108
# 3          1   Aguascalientes  2018  0.420223               3650.282928
# 4          1   Aguascalientes  2019       NaN               3879.644560
# 5          1   Aguascalientes  2020  0.395063               4577.047639
# 6          2  Baja California  2015       NaN               4476.544790
# 7          2  Baja California  2016  0.424442               4765.312201
# 8          2  Baja California  2017       NaN               4595.678591
# 9          2  Baja California  2018  0.390773               4930.243961
#
#    poblacion_economicamente_activa  inversion_extranjera_anual  \
# 0                     5.429885e+05                  812.584154
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 21 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   id_estado                                      192 non-null    int64
#  1   estado                                         192 non-null    object
#  2   año                                            192 non-null    int64
#  3   gini                                           96 non-null     float64
#  4   salario_mensual_promedio                       192 non-null    float64
#  5   poblacion_economicamente_activa                192 non-null    float64
#  6   inversion_extranjera_anual                     192 non-null    float64
#  7   Desarrollo Económico                           192 non-null    float64
#  8   Desarrollo Social                              192 non-null    float64
# ...
